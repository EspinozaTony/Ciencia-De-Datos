# %% [markdown]
# # Unidad 1 – Ciencia de Datos
# ## EDA y Limpieza de Datos: Online Retail Dataset
# **TecNM Campus Apatzingán | Ingeniería en Sistemas Computacionales**
#
# ---
#
# ### Reflexión inicial
# Antes de ejecutar cualquier celda, responde aquí:
# - ¿Qué tipo de problemas de calidad esperarías encontrar en un dataset de transacciones comerciales reales?
# - ¿Qué columnas crees que serán más problemáticas y por qué?
#
# *Escribe tu reflexión aquí...*

# %% [markdown]
# ## Paso 1 – Carga de Librerías y Datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Carga directa desde UCI Machine Learning Repository
# Nota: puede tardar ~1 minuto por el tamaño del archivo (.xlsx ~23 MB)
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00352/Online%20Retail.xlsx'
df = pd.read_excel(url)

# Verifica que la carga fue correcta
print(f'Dataset cargado: {df.shape[0]:,} filas × {df.shape[1]} columnas')

# %% [markdown]
# ## Paso 2 – Exploración Inicial

# %%
# Explora la estructura general del dataset
# Usa: df.shape, df.head(), df.tail(), df.info()
# Tu código aquí...

# %% [markdown]
# **Responde las preguntas guía:**
# 1. ¿Cuántas filas y columnas tiene el dataset?
# 2. ¿Qué columnas presentan valores faltantes a primera vista?
# 3. ¿El tipo de dato de InvoiceDate es el correcto? ¿Qué implicaciones tiene?
#
# *Escribe tus respuestas aquí...*

# %% [markdown]
# ## Paso 3 – Estadística Descriptiva Básica

# %%
# Calcula estadísticas descriptivas de las variables numéricas
# Incluye: media, mediana, moda de Quantity y UnitPrice
# Genera histogramas de distribución para ambas columnas
# Tu código aquí...

# %% [markdown]
# **Responde las preguntas guía:**
# 1. ¿La media y la mediana de Quantity son similares? ¿Qué indica eso sobre la distribución?
# 2. ¿El valor mínimo de Quantity o UnitPrice tiene sentido comercialmente? ¿Qué podría explicarlo?
# 3. ¿La distribución de UnitPrice es simétrica o asimétrica? ¿Por qué?
#
# *Escribe tus respuestas aquí...*

# %% [markdown]
# ## Paso 4 – Detección de Valores Nulos

# %%
# Identifica cuántos valores faltan por columna y su porcentaje
# Visualiza el patrón de nulos con un mapa de calor (seaborn heatmap)
# Tu código aquí...

# %% [markdown]
# **Responde las preguntas guía:**
# 1. ¿Qué columnas tienen valores nulos y en qué porcentaje?
# 2. CustomerID tiene ~25% de nulos. ¿Es seguro eliminar esas filas? ¿Qué alternativa propondrías?
# 3. ¿Qué impacto tendría en el análisis ignorar las filas con Description nula?
#
# *Escribe tus respuestas aquí...*

# %% [markdown]
# ## Paso 5 – Detección de Valores Erróneos

# %%
# Investiga tres tipos de anomalías en el dataset:
#
# a) Cancelaciones: facturas cuyo InvoiceNo inicia con 'C'
#    ¿Cuántas hay? ¿Qué tienen de diferente respecto al resto?
#
# b) Precios inválidos: filas con UnitPrice igual a 0 o negativo
#    ¿Qué tipo de registros son? ¿Se deben conservar?
#
# c) Outliers en Quantity: usa un boxplot
#    ¿Qué tan extremos son los valores atípicos?
#
# Tu código aquí...

# %% [markdown]
# **Responde las preguntas guía:**
# 1. ¿Cuántas transacciones son cancelaciones? ¿Las incluirías en un análisis de ventas?
# 2. ¿Qué harías con las filas de UnitPrice igual a 0? ¿Eliminarlas o conservarlas con algún criterio?
# 3. ¿El valor máximo de Quantity es razonable en un contexto de ventas al mayoreo?
#
# *Escribe tus respuestas aquí...*

# %% [markdown]
# ## Paso 6 – Tratamiento y Limpieza de Datos

# %%
# Diseña y aplica tu pipeline de limpieza sobre una copia del DataFrame original
# Documenta cada decisión con un comentario: qué haces y por qué
# Al final genera un reporte: cuántos registros tenías vs. cuántos quedaron
#
# Considera: ¿qué haces con Description nula? ¿Con cancelaciones? 
# ¿Con precios inválidos? ¿Con CustomerID nulo?
#
# Tu código aquí...

# %% [markdown]
# **Responde las preguntas guía:**
# 1. ¿Qué porcentaje de registros se perdió tras la limpieza? ¿Es aceptable?
# 2. ¿El tratamiento de CustomerID nulo depende del objetivo del análisis? Explica con un ejemplo.
# 3. ¿Qué otros problemas de calidad identificaste que no se mencionan explícitamente en la guía?
#
# *Escribe tus respuestas aquí...*

# %% [markdown]
# ## Paso 7 – Encoding de Variables Categóricas

# %%
# Aplica Label Encoding y One-Hot Encoding a la columna Country
# Compara el resultado de ambas técnicas
# ¿Cuántas columnas genera cada una? ¿Qué información conserva o pierde cada enfoque?
#
# Tu código aquí...

# %% [markdown]
# **Responde las preguntas guía:**
# 1. ¿Por qué el One-Hot Encoding genera tantas columnas nuevas para Country?
# 2. ¿En qué situación preferirías Label Encoding sobre One-Hot? Da un ejemplo concreto.
# 3. ¿Cuál estrategia usarías para Country en este dataset y por qué?
#
# *Escribe tus respuestas aquí...*

# %% [markdown]
# ## Paso 8 – Análisis de Correlación e Insights

# %%
# Genera una matriz de correlación entre las variables numéricas
# Explora patrones relevantes: distribución por país, tendencias temporales,
# relación entre cantidad y precio
# Crea al menos 3 visualizaciones que respalden tus insights
#
# Tu código aquí...

# %% [markdown]
# ### Insights
#
# Redacta al menos **3 insights accionables**, cada uno con la siguiente estructura:
#
# ---
# **Insight 1:**
# - **Hallazgo:** *qué observaste (1-2 líneas)*
# - **Evidencia:** *referencia a la gráfica o tabla*
# - **Recomendación:** *qué acción tomaría la empresa*
#
# ---
# **Insight 2:**
# - **Hallazgo:**
# - **Evidencia:**
# - **Recomendación:**
#
# ---
# **Insight 3:**
# - **Hallazgo:**
# - **Evidencia:**
# - **Recomendación:**
